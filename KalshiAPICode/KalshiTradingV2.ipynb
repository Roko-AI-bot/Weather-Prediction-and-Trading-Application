# %%
# Welcome to the Kalshi REST v2 Starter Code!

# pypi client: recommended for more advanced programmers
import kalshi_python

# starter client: recommended for all levels of programming experience (what this client is implemented using)
from KalshiClientsBaseV2 import ExchangeClient
import time
import json
import uuid

# %%
# Demo https://demo.kalshi.co/

demo_email = "" # not included for submission
demo_password = "" # not included for submission
demo_api_base = "https://demo-api.kalshi.co/trade-api/v2"
exchange_client = ExchangeClient(exchange_api_base = demo_api_base, email = demo_email, password = demo_password)

# first we will check on the exchange status to confirm you are properly connected...
print(exchange_client.get_exchange_status())
# Out:
# {'exchange_active': True, 'trading_active': True}

# %%
# Event tickers for high temp for the cities: NYC, Miami, Austin, and Chicago
# Get info about current tickers
event_tickers = ['HIGHNY-24MAR22', 'HIGHMIA-24MAR22', 'HIGHAUS-24MAR22', 'HIGHCHI-24MAR22']

for event_ticker in event_tickers:
    event_params = {'event_ticker': event_ticker}
    event_response = exchange_client.get_event(**event_params)
    print('event object:', event_response['event'])
    print("markets in event_response payload:")
    for i in range(len(event_response['markets'])):
        print(event_response['markets'][i])
    print()
    print()
# Out:
# event object: {'event_ticker': 'HIGHNY-24MAR22', 'series_ticker': 'HIGHNY', 'sub_title': 'On Mar 22, 2024', 'title': 'Highest temperature in NYC on Mar 22, 2024?', 'mutually_exclusive': True, 'category': 'Climate and Weather', 'strike_date': '2024-03-23T03:59:00Z'}
# markets in event_response payload:
# {'ticker': 'HIGHNY-24MAR22-T41', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '40° or below', 'yes_sub_title': '40° or below', 'no_sub_title': 'Outside 40° or below', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 10, 'yes_ask': 70, 'no_bid': 0, 'no_ask': 0, 'last_price': 10, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 1083, 'volume_24h': 1083, 'liquidity': 277770, 'open_interest': 1031, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'less', 'cap_strike': 41, 'rules_primary': "If the highest temperature recorded in Central Park, New York for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is less than 41°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHNY-24MAR22-B41.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '41° to 42°', 'yes_sub_title': '41° to 42°', 'no_sub_title': 'Outside 41° to 42°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 1, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 194, 'volume_24h': 194, 'liquidity': 6251, 'open_interest': 135, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 41, 'cap_strike': 42, 'rules_primary': "If the highest temperature recorded in Central Park, New York for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 41-42°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHNY-24MAR22-B43.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '43° to 44°', 'yes_sub_title': '43° to 44°', 'no_sub_title': 'Outside 43° to 44°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 30, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 296, 'volume_24h': 296, 'liquidity': 421, 'open_interest': 270, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 43, 'cap_strike': 44, 'rules_primary': "If the highest temperature recorded in Central Park, New York for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 43-44°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHNY-24MAR22-B45.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '45° to 46°', 'yes_sub_title': '45° to 46°', 'no_sub_title': 'Outside 45° to 46°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 1, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 237, 'volume_24h': 237, 'liquidity': 5701, 'open_interest': 191, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 45, 'cap_strike': 46, 'rules_primary': "If the highest temperature recorded in Central Park, New York for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 45-46°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHNY-24MAR22-B47.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '47° to 48°', 'yes_sub_title': '47° to 48°', 'no_sub_title': 'Outside 47° to 48°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 268, 'volume_24h': 268, 'liquidity': 92241, 'open_interest': 213, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 47, 'cap_strike': 48, 'rules_primary': "If the highest temperature recorded in Central Park, New York for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 47-48°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHNY-24MAR22-T48', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '49° or above', 'yes_sub_title': '49° or above', 'no_sub_title': 'Outside 49° or above', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 30, 'yes_ask': 50, 'no_bid': 0, 'no_ask': 0, 'last_price': 30, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 298, 'volume_24h': 298, 'liquidity': 141820, 'open_interest': 257, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 48, 'rules_primary': "If the highest temperature recorded in Central Park, New York for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is greater than 48°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
#
#
# event object: {'event_ticker': 'HIGHMIA-24MAR22', 'series_ticker': 'HIGHMIA', 'sub_title': 'On Mar 22, 2024', 'title': 'Highest temperature in Miami on Mar 22, 2024?', 'mutually_exclusive': True, 'category': 'Climate and Weather', 'strike_date': '2024-03-23T03:59:00Z'}
# markets in event_response payload:
# {'ticker': 'HIGHMIA-24MAR22-T75', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '74° or below', 'yes_sub_title': '74° or below', 'no_sub_title': 'Outside 74° or below', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 10, 'yes_ask': 70, 'no_bid': 0, 'no_ask': 0, 'last_price': 10, 'previous_yes_bid': 0, 'previous_yes_ask': 1, 'previous_price': 0, 'volume': 319, 'volume_24h': 319, 'liquidity': 96292, 'open_interest': 290, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'less', 'cap_strike': 75, 'rules_primary': "If the highest temperature recorded in Miami, FL for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is less than 75°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHMIA-24MAR22-B75.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '75° to 76°', 'yes_sub_title': '75° to 76°', 'no_sub_title': 'Outside 75° to 76°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 1, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 43, 'volume_24h': 43, 'liquidity': 21901, 'open_interest': 42, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 75, 'cap_strike': 76, 'rules_primary': "If the highest temperature recorded in Miami, FL for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 75-76°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHMIA-24MAR22-B77.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '77° to 78°', 'yes_sub_title': '77° to 78°', 'no_sub_title': 'Outside 77° to 78°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 1, 'no_bid': 0, 'no_ask': 0, 'last_price': 70, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 202, 'volume_24h': 202, 'liquidity': 13931, 'open_interest': 201, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 77, 'cap_strike': 78, 'rules_primary': "If the highest temperature recorded in Miami, FL for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 77-78°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHMIA-24MAR22-B79.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '79° to 80°', 'yes_sub_title': '79° to 80°', 'no_sub_title': 'Outside 79° to 80°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 10, 'yes_ask': 50, 'no_bid': 0, 'no_ask': 0, 'last_price': 10, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 381, 'volume_24h': 381, 'liquidity': 134190, 'open_interest': 338, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 79, 'cap_strike': 80, 'rules_primary': "If the highest temperature recorded in Miami, FL for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 79-80°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHMIA-24MAR22-B81.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '81° to 82°', 'yes_sub_title': '81° to 82°', 'no_sub_title': 'Outside 81° to 82°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 1, 'no_bid': 0, 'no_ask': 0, 'last_price': 68, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 210, 'volume_24h': 210, 'liquidity': 9589, 'open_interest': 170, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 81, 'cap_strike': 82, 'rules_primary': "If the highest temperature recorded in Miami, FL for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 81-82°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHMIA-24MAR22-T82', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '83° or above', 'yes_sub_title': '83° or above', 'no_sub_title': 'Outside 83° or above', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 410, 'volume_24h': 410, 'liquidity': 220601, 'open_interest': 410, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 82, 'rules_primary': "If the highest temperature recorded in Miami, FL for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is greater than 82°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
#
#
# event object: {'event_ticker': 'HIGHAUS-24MAR22', 'series_ticker': 'HIGHAUS', 'sub_title': 'On Mar 22, 2024', 'title': 'Highest temperature in Austin on Mar 22, 2024?', 'mutually_exclusive': True, 'category': 'Climate and Weather', 'strike_date': '2024-03-23T04:59:00Z'}
# markets in event_response payload:
# {'ticker': 'HIGHAUS-24MAR22-T72', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '71° or below', 'yes_sub_title': '71° or below', 'no_sub_title': 'Outside 71° or below', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T04:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 50, 'yes_ask': 86, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 523, 'volume_24h': 523, 'liquidity': 96014, 'open_interest': 420, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'less', 'cap_strike': 72, 'rules_primary': "If the highest temperature recorded in Austin Bergstrom for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is less than 72°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM CT on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHAUS-24MAR22-B72.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '72° to 73°', 'yes_sub_title': '72° to 73°', 'no_sub_title': 'Outside 72° to 73°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T04:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 1, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 13, 'volume_24h': 13, 'liquidity': 23401, 'open_interest': 12, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 72, 'cap_strike': 73, 'rules_primary': "If the highest temperature recorded in Austin Bergstrom for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 72-73°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM CT on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHAUS-24MAR22-B74.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '74° to 75°', 'yes_sub_title': '74° to 75°', 'no_sub_title': 'Outside 74° to 75°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T04:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 99, 'previous_yes_bid': 0, 'previous_yes_ask': 1, 'previous_price': 0, 'volume': 412, 'volume_24h': 412, 'liquidity': 991, 'open_interest': 410, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 74, 'cap_strike': 75, 'rules_primary': "If the highest temperature recorded in Austin Bergstrom for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 74-75°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM CT on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHAUS-24MAR22-B76.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '76° to 77°', 'yes_sub_title': '76° to 77°', 'no_sub_title': 'Outside 76° to 77°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T04:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 70, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 402, 'volume_24h': 402, 'liquidity': 1, 'open_interest': 400, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 76, 'cap_strike': 77, 'rules_primary': "If the highest temperature recorded in Austin Bergstrom for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 76-77°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM CT on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHAUS-24MAR22-B78.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '78° to 79°', 'yes_sub_title': '78° to 79°', 'no_sub_title': 'Outside 78° to 79°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T04:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 10, 'yes_ask': 50, 'no_bid': 0, 'no_ask': 0, 'last_price': 10, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 243, 'volume_24h': 243, 'liquidity': 91810, 'open_interest': 165, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 78, 'cap_strike': 79, 'rules_primary': "If the highest temperature recorded in Austin Bergstrom for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is between 78-79°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM CT on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
# {'ticker': 'HIGHAUS-24MAR22-T79', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '80° or above', 'yes_sub_title': '80° or above', 'no_sub_title': 'Outside 80° or above', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T04:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 10, 'yes_ask': 50, 'no_bid': 0, 'no_ask': 0, 'last_price': 10, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 293, 'volume_24h': 293, 'liquidity': 89560, 'open_interest': 211, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 79, 'rules_primary': "If the highest temperature recorded in Austin Bergstrom for March 22, 2024 as reported by the National Weather Service's Daily Climate Report, is greater than 79°, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n \nThe Last Trading Time will be 11:59 PM CT on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.'}
#
#
# event object: {'event_ticker': 'HIGHCHI-24MAR22', 'series_ticker': 'HIGHCHI', 'sub_title': 'On Mar 22, 2024', 'title': 'Highest temperature in Chicago on Mar 22, 2024?', 'mutually_exclusive': True, 'category': 'Climate and Weather', 'strike_date': '2024-03-23T03:59:00Z'}
# markets in event_response payload:
# {'ticker': 'HIGHCHI-24MAR22-T42', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '41° or below', 'yes_sub_title': '41° or below', 'no_sub_title': 'Outside 41° or below', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 10, 'yes_ask': 70, 'no_bid': 0, 'no_ask': 0, 'last_price': 10, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 428, 'volume_24h': 428, 'liquidity': 221760, 'open_interest': 384, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'less', 'cap_strike': 42, 'rules_primary': "If the highest temperature recorded at Chicago Midway, IL for March 22, 2024, is less than 42° according to the NWS's Daily Climate Report, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n\nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.\n\nAs a reminder, the Underlying is not the NWS NOWData data source. As noted in the Rulebook, for the actual Underlying, please go to the Source Agency link, click on "Observed Weather", then choose "Chicago Midway, IL".'}
# {'ticker': 'HIGHCHI-24MAR22-B42.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '42° to 43°', 'yes_sub_title': '42° to 43°', 'no_sub_title': 'Outside 42° to 43°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 50, 'yes_ask': 62, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 728, 'volume_24h': 728, 'liquidity': 43252, 'open_interest': 625, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 42, 'cap_strike': 43, 'rules_primary': "If the highest temperature recorded at Chicago Midway, IL for March 22, 2024, is between 42-43° according to the NWS's Daily Climate Report, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n\nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.\n\nAs a reminder, the Underlying is not the NWS NOWData data source. As noted in the Rulebook, for the actual Underlying, please go to the Source Agency link, click on "Observed Weather", then choose "Chicago Midway, IL".'}
# {'ticker': 'HIGHCHI-24MAR22-B44.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '44° to 45°', 'yes_sub_title': '44° to 45°', 'no_sub_title': 'Outside 44° to 45°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 30, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 240, 'volume_24h': 240, 'liquidity': 14671, 'open_interest': 227, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 44, 'cap_strike': 45, 'rules_primary': "If the highest temperature recorded at Chicago Midway, IL for March 22, 2024, is between 44-45° according to the NWS's Daily Climate Report, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n\nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.\n\nAs a reminder, the Underlying is not the NWS NOWData data source. As noted in the Rulebook, for the actual Underlying, please go to the Source Agency link, click on "Observed Weather", then choose "Chicago Midway, IL".'}
# {'ticker': 'HIGHCHI-24MAR22-B46.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '46° to 47°', 'yes_sub_title': '46° to 47°', 'no_sub_title': 'Outside 46° to 47°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 30, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 279, 'volume_24h': 279, 'liquidity': 1471, 'open_interest': 200, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 46, 'cap_strike': 47, 'rules_primary': "If the highest temperature recorded at Chicago Midway, IL for March 22, 2024, is between 46-47° according to the NWS's Daily Climate Report, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n\nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.\n\nAs a reminder, the Underlying is not the NWS NOWData data source. As noted in the Rulebook, for the actual Underlying, please go to the Source Agency link, click on "Observed Weather", then choose "Chicago Midway, IL".'}
# {'ticker': 'HIGHCHI-24MAR22-B48.5', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '48° to 49°', 'yes_sub_title': '48° to 49°', 'no_sub_title': 'Outside 48° to 49°', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 0, 'last_price': 30, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 257, 'volume_24h': 257, 'liquidity': 3151, 'open_interest': 214, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'between', 'floor_strike': 48, 'cap_strike': 49, 'rules_primary': "If the highest temperature recorded at Chicago Midway, IL for March 22, 2024, is between 48-49° according to the NWS's Daily Climate Report, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n\nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.\n\nAs a reminder, the Underlying is not the NWS NOWData data source. As noted in the Rulebook, for the actual Underlying, please go to the Source Agency link, click on "Observed Weather", then choose "Chicago Midway, IL".'}
# {'ticker': 'HIGHCHI-24MAR22-T49', 'event_ticker': '', 'market_type': 'binary', 'title': '', 'subtitle': '50° or above', 'yes_sub_title': '50° or above', 'no_sub_title': 'Outside 50° or above', 'open_time': '2024-03-21T14:00:00Z', 'close_time': '2024-03-23T03:59:00Z', 'expected_expiration_time': '2024-03-23T14:00:00Z', 'expiration_time': '2024-03-29T14:00:00Z', 'latest_expiration_time': '2024-03-29T14:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 1, 'no_bid': 0, 'no_ask': 0, 'last_price': 50, 'previous_yes_bid': 99, 'previous_yes_ask': 100, 'previous_price': 0, 'volume': 304, 'volume_24h': 304, 'liquidity': 4901, 'open_interest': 278, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 49, 'rules_primary': "If the highest temperature recorded at Chicago Midway, IL for March 22, 2024, is greater than 49° according to the NWS's Daily Climate Report, then the market resolves to Yes.", 'rules_secondary': 'Please be advised to check to see what temperatures have occurred previously in the day. While the market resolves based on the finalized report from the NWS, traders should use other data sources--including other preliminary NWS reporting--to inform their trades.\n\nThe Last Trading Time will be 11:59 PM ET on March 22, 2024 regardless of any data releases or events occurring. Expiration will occur on the sooner of the first 10:00 AM following the release of the data for March 22, 2024, or one week after March 22, 2024.\n\nAs a reminder, the Underlying is not the NWS NOWData data source. As noted in the Rulebook, for the actual Underlying, please go to the Source Agency link, click on "Observed Weather", then choose "Chicago Midway, IL".'}

# %%
# Check current balance
current_balance = exchange_client.get_balance()
current_balance
# Out:
# {'balance': 1070161}

# %%
# Check previous settlements

settlement_params = {'limit': None,
                        'cursor': None}

settlements = exchange_client.get_portfolio_settlements(**settlement_params)
settlements
# Out:
# {'settlements': [{'ticker': 'HIGHMIA-24MAR21-B81.5',
#    'market_result': 'yes',
#    'yes_count': 10,
#    'yes_total_cost': 680,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 1000,
#    'settled_time': '2024-03-22T12:01:20.403714Z'},
#   {'ticker': 'HIGHAUS-24MAR21-T68',
#    'market_result': 'yes',
#    'yes_count': 10,
#    'yes_total_cost': 900,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 1000,
#    'settled_time': '2024-03-22T12:01:12.402932Z'},
#   {'ticker': 'HIGHNY-24MAR21-B44.5',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 500,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-22T12:01:04.403532Z'},
#   {'ticker': 'HIGHCHI-24MAR21-T43',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 900,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-22T12:00:55.403313Z'},
#   {'ticker': 'HIGHMIA-24MAR20-B80.5',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 900,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-21T12:01:12.451541Z'},
#   {'ticker': 'HIGHAUS-24MAR20-T63',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 451,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-21T12:01:04.407001Z'},
#   {'ticker': 'HIGHNY-24MAR20-B51.5',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 451,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-21T12:00:56.406226Z'},
#   {'ticker': 'HIGHCHI-24MAR20-B37.5',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 451,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-21T12:00:47.42672Z'},
#   {'ticker': 'HIGHMIA-24MAR19-T79',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 900,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-20T12:01:16.311217Z'},
#   {'ticker': 'HIGHAUS-24MAR19-T66',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-20T12:01:08.311264Z'},
#   {'ticker': 'HIGHNY-24MAR19-T52',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-20T12:00:59.351508Z'},
#   {'ticker': 'HIGHCHI-24MAR19-T51',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 900,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-20T12:00:50.310654Z'},
#   {'ticker': 'HIGHMIA-24MAR18-B89.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-19T12:01:11.315693Z'},
#   {'ticker': 'HIGHAUS-24MAR18-T65',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 495,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-19T12:01:02.315677Z'},
#   {'ticker': 'HIGHNY-24MAR18-T54',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-19T12:00:53.386179Z'},
#   {'ticker': 'HIGHCHI-24MAR18-B36.5',
#    'market_result': 'yes',
#    'yes_count': 5,
#    'yes_total_cost': 197,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 500,
#    'settled_time': '2024-03-19T12:00:45.37619Z'},
#   {'ticker': 'HIGHMIA-24MAR08-T86',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-09T13:00:34.551272Z'},
#   {'ticker': 'HIGHAUS-24MAR08-B79.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-09T13:00:27.566999Z'},
#   {'ticker': 'HIGHNY-24MAR08-B56.5',
#    'market_result': 'yes',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 500,
#    'settled_time': '2024-03-09T13:00:19.570992Z'},
#   {'ticker': 'HIGHCHI-24MAR08-B49.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-09T13:00:11.571106Z'},
#   {'ticker': 'HIGHMIA-24MAR07-B83.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-08T13:01:20.560905Z'},
#   {'ticker': 'HIGHAUS-24MAR07-B75.5',
#    'market_result': 'yes',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-08T13:01:12.620667Z'},
#   {'ticker': 'HIGHNY-24MAR07-B52.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 361,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-08T13:01:04.550663Z'},
#   {'ticker': 'HIGHCHI-24MAR07-B49.5',
#    'market_result': 'yes',
#    'yes_count': 5,
#    'yes_total_cost': 361,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 500,
#    'settled_time': '2024-03-08T13:00:54.550645Z'},
#   {'ticker': 'HIGHMIA-24MAR06-T84',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-07T13:01:06.967913Z'},
#   {'ticker': 'HIGHAUS-24MAR06-T79',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 375,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-07T13:00:58.95693Z'},
#   {'ticker': 'HIGHNY-24MAR06-B52.5',
#    'market_result': 'yes',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 500,
#    'settled_time': '2024-03-07T13:00:50.962751Z'},
#   {'ticker': 'HIGHCHI-24MAR06-T44',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 375,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-07T13:00:41.986987Z'},
#   {'ticker': 'HIGHMIA-24MAR05-B78.5',
#    'market_result': 'no',
#    'yes_count': 3,
#    'yes_total_cost': 120,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-06T13:01:12.972806Z'},
#   {'ticker': 'HIGHAUS-24MAR05-B85.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 350,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-06T13:01:05.957514Z'},
#   {'ticker': 'HIGHNY-24MAR05-T47',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 350,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-06T13:00:56.967067Z'},
#   {'ticker': 'HIGHCHI-24MAR05-B48.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 350,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-06T13:00:48.972148Z'},
#   {'ticker': 'HIGHMIA-24MAR04-B79.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-05T13:01:10.805849Z'},
#   {'ticker': 'HIGHAUS-24MAR04-B77.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-05T13:01:02.805847Z'},
#   {'ticker': 'HIGHNY-24MAR04-T61',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-05T13:00:54.830648Z'},
#   {'ticker': 'HIGHCHI-24MAR04-B74.5',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 450,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-05T13:00:46.830706Z'},
#   {'ticker': 'HIGHMIA-24MAR01-B77.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 50,
#    'no_total_cost': 2500,
#    'revenue': 5000,
#    'settled_time': '2024-03-02T13:01:10.811173Z'},
#   {'ticker': 'HIGHAUS-24MAR01-B74.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 31,
#    'no_total_cost': 90,
#    'revenue': 3100,
#    'settled_time': '2024-03-02T13:01:02.810982Z'},
#   {'ticker': 'HIGHNY-24MAR01-B46.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 41,
#    'no_total_cost': 2870,
#    'revenue': 4100,
#    'settled_time': '2024-03-02T13:00:55.805693Z'},
#   {'ticker': 'HIGHCHI-24MAR01-B48.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 38,
#    'no_total_cost': 1900,
#    'revenue': 3800,
#    'settled_time': '2024-03-02T13:00:46.810536Z'},
#   {'ticker': 'HIGHMIA-24FEB29-B79.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 32,
#    'no_total_cost': 1920,
#    'revenue': 3200,
#    'settled_time': '2024-03-01T13:01:14.829139Z'},
#   {'ticker': 'HIGHMIA-24FEB29-B77.5',
#    'market_result': 'no',
#    'yes_count': 1,
#    'yes_total_cost': 1,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-03-01T13:01:14.829139Z'},
#   {'ticker': 'HIGHAUS-24FEB29-B55.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 20,
#    'no_total_cost': 1343,
#    'revenue': 2000,
#    'settled_time': '2024-03-01T13:01:07.829238Z'},
#   {'ticker': 'HIGHNY-24FEB29-T42',
#    'market_result': 'yes',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 19,
#    'no_total_cost': 950,
#    'revenue': 0,
#    'settled_time': '2024-03-01T13:00:59.828651Z'},
#   {'ticker': 'HIGHNY-24FEB29-B41.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 291,
#    'no_total_cost': 9660,
#    'revenue': 29100,
#    'settled_time': '2024-03-01T13:00:59.828651Z'},
#   {'ticker': 'HIGHCHI-24FEB29-B43.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 81,
#    'no_total_cost': 4900,
#    'revenue': 8100,
#    'settled_time': '2024-03-01T13:00:50.829234Z'},
#   {'ticker': 'HIGHMIA-24FEB28-B77.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 38,
#    'no_total_cost': 1900,
#    'revenue': 3800,
#    'settled_time': '2024-02-29T13:01:14.83147Z'},
#   {'ticker': 'HIGHMIA-24FEB28-B75.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 1,
#    'no_total_cost': 1,
#    'revenue': 100,
#    'settled_time': '2024-02-29T13:01:14.83147Z'},
#   {'ticker': 'HIGHAUS-24FEB28-T59',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 1,
#    'no_total_cost': 90,
#    'revenue': 100,
#    'settled_time': '2024-02-29T13:01:06.806551Z'},
#   {'ticker': 'HIGHAUS-24FEB28-B59.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 22,
#    'no_total_cost': 1980,
#    'revenue': 2200,
#    'settled_time': '2024-02-29T13:01:06.806551Z'},
#   {'ticker': 'HIGHNY-24FEB28-B59.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 9,
#    'no_total_cost': 450,
#    'revenue': 900,
#    'settled_time': '2024-02-29T13:00:57.811335Z'},
#   {'ticker': 'HIGHCHI-24FEB28-B30.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 5,
#    'no_total_cost': 250,
#    'revenue': 500,
#    'settled_time': '2024-02-29T13:00:42.811274Z'},
#   {'ticker': 'HIGHMIA-24FEB27-B76.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 121,
#    'no_total_cost': 940,
#    'revenue': 12100,
#    'settled_time': '2024-02-28T13:01:15.436914Z'},
#   {'ticker': 'HIGHMIA-24FEB27-B74.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 209,
#    'no_total_cost': 938,
#    'revenue': 20900,
#    'settled_time': '2024-02-28T13:01:15.436914Z'},
#   {'ticker': 'HIGHAUS-24FEB27-B85.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 58,
#    'no_total_cost': 1430,
#    'revenue': 5800,
#    'settled_time': '2024-02-28T13:01:07.426597Z'},
#   {'ticker': 'HIGHNY-24FEB27-B58.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 6,
#    'no_total_cost': 420,
#    'revenue': 600,
#    'settled_time': '2024-02-28T13:00:59.546552Z'},
#   {'ticker': 'HIGHNY-24FEB27-B54.5',
#    'market_result': 'yes',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 5,
#    'no_total_cost': 450,
#    'revenue': 0,
#    'settled_time': '2024-02-28T13:00:59.546552Z'},
#   {'ticker': 'HIGHCHI-24FEB27-T71',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 127,
#    'no_total_cost': 960,
#    'revenue': 12700,
#    'settled_time': '2024-02-28T13:00:51.431367Z'},
#   {'ticker': 'HIGHMIA-24FEB26-B75.5',
#    'market_result': 'yes',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 1,
#    'no_total_cost': 50,
#    'revenue': 0,
#    'settled_time': '2024-02-27T13:01:03.183004Z'},
#   {'ticker': 'HIGHAUS-24FEB26-T81',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 5,
#    'no_total_cost': 450,
#    'revenue': 500,
#    'settled_time': '2024-02-27T13:00:56.203366Z'},
#   {'ticker': 'HIGHNY-24FEB26-B55.5',
#    'market_result': 'yes',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-02-27T13:00:48.178427Z'},
#   {'ticker': 'HIGHNY-24FEB26-B51.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 9,
#    'no_total_cost': 450,
#    'revenue': 900,
#    'settled_time': '2024-02-27T13:00:48.178427Z'},
#   {'ticker': 'HIGHCHI-24FEB26-T63',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 9,
#    'no_total_cost': 450,
#    'revenue': 900,
#    'settled_time': '2024-02-27T13:00:39.178465Z'},
#   {'ticker': 'HIGHCHI-24FEB26-B63.5',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 1,
#    'no_total_cost': 50,
#    'revenue': 100,
#    'settled_time': '2024-02-27T13:00:39.178465Z'}],
#  'cursor': ''}

# %%
# Make new orders
# Buy at least one position for each city,

tickers = ['HIGHNY-24MAR22-T48','HIGHMIA-24MAR22-B79.5','HIGHCHI-24MAR22-T42', 'HIGHAUS-24MAR22-B72.5']


for ticker in tickers:
    order_params = {'ticker':ticker,
                        'client_order_id':str(uuid.uuid4()),
                        'type':'limit',
                        'action':'buy',
                        'side':'yes',
                        'count':10,
                        'yes_price':90, # yes_price = 100 - no_price
                        'no_price':None, # no_price = 100 - yes_price
                        'expiration_ts':None,
                        'sell_position_floor':None,
                        'buy_max_cost':None}

    exchange_client.create_order(**order_params)
# Out:
# {'ticker': 'HIGHNY-24MAR22-T48', 'client_order_id': 'e61e9a70-7365-4ec4-a70a-0809a330cdd6', 'side': 'yes', 'action': 'buy', 'count': 10, 'type': 'limit', 'yes_price': 90}
# {'ticker': 'HIGHMIA-24MAR22-B79.5', 'client_order_id': '6c28a929-60c0-4cf3-be78-cbae1bd2fb76', 'side': 'yes', 'action': 'buy', 'count': 10, 'type': 'limit', 'yes_price': 90}
# {'ticker': 'HIGHCHI-24MAR22-T42', 'client_order_id': '76c687db-0638-4551-a049-f973c081c650', 'side': 'yes', 'action': 'buy', 'count': 10, 'type': 'limit', 'yes_price': 90}
# {'ticker': 'HIGHAUS-24MAR22-B72.5', 'client_order_id': '2ba905ea-cbe0-493d-af9b-d3a3157894a9', 'side': 'yes', 'action': 'buy', 'count': 10, 'type': 'limit', 'yes_price': 90}
